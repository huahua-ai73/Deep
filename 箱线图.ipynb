# %%
 
# 导入第三方模块
 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#pandas读取excel数据
a =  pd.read_excel(r'xh.xlsx')
#将excel数据转换成数组
data = np.array(a)
#切片,将x的全部行，到1050列作为图中的y
x,y= data[:, :1050],data[:, 1050]
print(x.shape, y.shape) 
 
'''# 读取Titanic数据集
 
titanic = pd.read_csv('titanic_train.csv')
 
# 检查年龄是否有缺失
 
any(titanic.Age.isnull())
 
# 不妨删除含有缺失年龄的观察
 
titanic.dropna(subset=['Age'], inplace=True)
'''
# Out:
# (530, 1050) (530,)
# "# 读取Titanic数据集\n \ntitanic = pd.read_csv('titanic_train.csv')\n \n# 检查年龄是否有缺失\n \nany(titanic.Age.isnull())\n \n# 不妨删除含有缺失年龄的观察\n \ntitanic.dropna(subset=['Age'], inplace=True)\n"

# %%
 
# 设置图形的显示风格
 
plt.style.use('ggplot')
 
 
 
# 设置中文和负号正常显示
 
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
 
plt.rcParams['axes.unicode_minus'] = False
 
 
 
# 绘图：整体乘客的年龄箱线图
 
plt.boxplot(x = x, # 指定绘图数据
 
            patch_artist=True, # 要求用自定义颜色填充盒形图，默认白色填充
 
            showmeans=True, # 以点的形式显示均值
 
            boxprops = {'color':'black','facecolor':'#9999ff'}, # 设置箱体属性，填充色和边框色
 
            flierprops = {'marker':'o','markerfacecolor':'red','color':'black'}, # 设置异常值属性，点的形状、填充色和边框色
 
            meanprops = {'marker':'D','markerfacecolor':'indianred'}, # 设置均值点的属性，点的形状、填充色
 
            medianprops = {'linestyle':'--','color':'orange'}) # 设置中位数线的属性，线的类型和颜色

# 设置y轴的范围
 
plt.ylim(0,0.5)

# 去除箱线图的上边框与右边框的刻度标签
 
plt.tick_params(top='off', right='off')
 
# 显示图形
 
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#pandas读取excel数据
a =  pd.read_excel(r'xh.xlsx')
#将excel数据转换成数组
data = np.array(a)
#切片,将x的全部行，到1050列作为图中的y
x= data[:, 800:850]

# %%
x
# Out:
# array([[0.26497   , 0.26427745, 0.26377585, ..., 0.35882735, 0.3596113 ,
#         0.36031695],
#        [0.28125605, 0.28053975, 0.28006545, ..., 0.39368725, 0.39452325,
#         0.39527765],
#        [0.28345295, 0.28274025, 0.2822558 , ..., 0.39316365, 0.3940242 ,
#         0.394801  ],
#        ...,
#        [0.2722378 , 0.27129365, 0.2705534 , ..., 0.359562  , 0.360156  ,
#         0.3606783 ],
#        [0.28017585, 0.27918305, 0.2783815 , ..., 0.3680544 , 0.36863335,
#         0.3691388 ],
#        [0.2576916 , 0.2567772 , 0.2560386 , ..., 0.33869555, 0.33933355,
#         0.33990855]])

# %%
 
# 设置图形的显示风格
 
plt.style.use('ggplot')
 
 
 
# 设置中文和负号正常显示
 
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
 
plt.rcParams['axes.unicode_minus'] = False
# 设置figure_size尺寸
plt.rcParams['figure.figsize'] = (80.0, 10.0) # 设置figure_size尺寸

 
# 绘图：整体乘客的年龄箱线图
 
plt.boxplot(x = x, # 指定绘图数据
 
            patch_artist=True, # 要求用自定义颜色填充盒形图，默认白色填充
 
            showmeans=True, # 以点的形式显示均值
 
            boxprops = {'color':'black','facecolor':'#9999ff'}, # 设置箱体属性，填充色和边框色
 
            flierprops = {'marker':'o','markerfacecolor':'red','color':'black'}, # 设置异常值属性，点的形状、填充色和边框色
 
            meanprops = {'marker':'D','markerfacecolor':'indianred'}, # 设置均值点的属性，点的形状、填充色
 
            medianprops = {'linestyle':'--','color':'orange'}) # 设置中位数线的属性，线的类型和颜色

# 设置y轴的范围
 
plt.ylim(0,0.5)
# 去除箱线图的上边框与右边框的刻度标签
 
plt.tick_params(top='off', right='off')
plt.figure(figsize=(10,10),dpi = 180)
 
# 显示图形
 
plt.show()
